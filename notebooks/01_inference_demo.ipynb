# %% [markdown]
# # Inference Demo
#
# Minimal notebook for running the required inference entry point.

# %%
# !python ../inference.py --image ../1-s2.0-S1684118220300682-main.pdf-002-a1.png --checkpoint ../checkpoints/davit_pneumonia_detection.bin
